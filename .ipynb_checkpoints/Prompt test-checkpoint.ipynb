# %%
import os
from openai import OpenAI
from IPython.display import display, Markdown

# %%
context = "system: You are a helpful agent. user: "+negative
client = OpenAI()
response = client.responses.create(
    model="gpt-5-mini",
    input= context
)

# %%
r1 = response.output_text
context += "agent: "
context += r1
display(Markdown(r1))

# %%
context += "user: 但是"
context += positive
response = client.responses.create(
    model="gpt-5-mini",
    input=context
)

# %%
context += "agent: "
context += response.output_text
display(Markdown(response.output_text))

# %%
context += "user: "
context += "他有没有变好的可能"
response = client.responses.create(
    model="gpt-5-mini",
    input=context
)

# %%
context += "agent: "
context += response.output_text
display(Markdown(response.output_text))

# %%
client = OpenAI(api_key=os.environ.get('DEEPSEEK_API_KEY'), base_url="https://api.deepseek.com")
context = [
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": negative+""},
    ]
response = client.chat.completions.create(
    model="deepseek-chat",
    messages=context,
    stream=False
)

r1 = response.choices[0].message.content
context.append({"role": "system", "content": r1})
display(Markdown(r1))

# %%
client = OpenAI(api_key=os.environ.get('DEEPSEEK_API_KEY'), base_url="https://api.deepseek.com")
context.append({"role": "user", "content": "但是"+positive})
response = client.chat.completions.create(
    model="deepseek-chat",
    messages=context,
    stream=False
)

r1 = response.choices[0].message.content
context.append({"role": "system", "content": r1})
display(Markdown(r1))

# %%
client = OpenAI(api_key=os.environ.get('DEEPSEEK_API_KEY'), base_url="https://api.deepseek.com")
context.append({"role": "user", "content": "他有没有变好的可能"})
response = client.chat.completions.create(
    model="deepseek-chat",
    messages=context,
    stream=False
)

r1 = response.choices[0].message.content
context.append({"role": "system", "content": r1})
display(Markdown(r1))
